# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulin05/EIP-4/blob/master/Week-4/Assignment%204B/Assignment_4B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %%
# Training parameters
batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Model name, depth and version
model_type = 'ResNet18v1'

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 45:
        lr *= 0.5e-1
    elif epoch > 35:
        lr *= 1e-1
    elif epoch > 25:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet18(input_shape, num_filters=16, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, num_filters
    stage 1: 16x16, num_filters*2
    stage 2:  8x8,  num_filters*4
    stage 4:  4x4,  num_filters*8

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """

    # 2 resnet blocks in each stage (with 2 resnet layers in each resnet block)
    num_res_blocks = 2

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(4):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # average pool the last layer
    x = AveragePooling2D(pool_size=4)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet18(input_shape=input_shape)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)

# Prepare model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
# Out:
# Learning rate:  0.001
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 16)   448         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 16)   64          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 16)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 16)   2320        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 16)   64          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 16)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 16)   2320        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 16)   64          conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 32, 16)   0           activation_18[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 16)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 16)   2320        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 16)   64          conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 16)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 16)   2320        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 16)   64          conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 32, 16)   0           activation_20[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 16)   0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 32)   4640        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 32)   128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 32)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 32)   9248        activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 32)   544         activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 32)   128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 32)   0           conv2d_28[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 32)   0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 32)   9248        activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 32)   128         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 32)   9248        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 32)   128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 32)   0           activation_24[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 32)   0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 64)     18496       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 64)     256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 64)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 64)     36928       activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 64)     2112        activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 64)     256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 8, 8, 64)     0           conv2d_33[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 64)     0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 64)     36928       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 64)     256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 8, 8, 64)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 64)     36928       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 64)     256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 8, 8, 64)     0           activation_28[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 8, 8, 64)     0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 4, 4, 128)    73856       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4, 4, 128)    512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 4, 4, 128)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 4, 4, 128)    147584      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 4, 4, 128)    8320        activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 4, 4, 128)    512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, 4, 128)    0           conv2d_38[0][0]
#                                                                  batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 4, 4, 128)    0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 4, 4, 128)    147584      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 4, 4, 128)    512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 4, 4, 128)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 4, 4, 128)    147584      activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 4, 4, 128)    512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 4, 4, 128)    0           activation_32[0][0]
#                                                                  batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 4, 4, 128)    0           add_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 128)    0           activation_34[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 128)          0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           1290        flatten_2[0][0]
# ==================================================================================================
# Total params: 704,170
# Trainable params: 702,218
# Non-trainable params: 1,952
# __________________________________________________________________________________________________
# ResNet18v1

# %%
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
def get_random_eraser(p=0.4, s_l=0.02, s_h=0.2, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # cutout augmentation
        preprocessing_function=get_random_eraser(v_l=0,v_h=50,pixel_level=False),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0
        )

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
# Learning rate:  0.001
# 391/391 [==============================] - 53s 137ms/step - loss: 2.0638 - acc: 0.3308 - val_loss: 1.9236 - val_acc: 0.3966
#
# Epoch 00001: val_acc improved from -inf to 0.39660, saving model to /content/saved_models/cifar10_ResNet18v1_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 1.5729 - acc: 0.5061 - val_loss: 1.9958 - val_acc: 0.4753
#
# Epoch 00002: val_acc improved from 0.39660 to 0.47530, saving model to /content/saved_models/cifar10_ResNet18v1_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 1.3278 - acc: 0.5990 - val_loss: 1.3685 - val_acc: 0.5966
#
# Epoch 00003: val_acc improved from 0.47530 to 0.59660, saving model to /content/saved_models/cifar10_ResNet18v1_model.003.h5
# Epoch 4/50
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 1.1787 - acc: 0.6530 - val_loss: 1.1821 - val_acc: 0.6495
#
# Epoch 00004: val_acc improved from 0.59660 to 0.64950, saving model to /content/saved_models/cifar10_ResNet18v1_model.004.h5
# Epoch 5/50
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 1.0767 - acc: 0.6879 - val_loss: 1.0813 - val_acc: 0.6984
#
# Epoch 00005: val_acc improved from 0.64950 to 0.69840, saving model to /content/saved_models/cifar10_ResNet18v1_model.005.h5
# Epoch 6/50
# Learning rate:  0.001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.9985 - acc: 0.7157 - val_loss: 1.1035 - val_acc: 0.7056
#
# Epoch 00006: val_acc improved from 0.69840 to 0.70560, saving model to /content/saved_models/cifar10_ResNet18v1_model.006.h5
# Epoch 7/50
# Learning rate:  0.001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.9436 - acc: 0.7367 - val_loss: 1.0553 - val_acc: 0.7112
#
# Epoch 00007: val_acc improved from 0.70560 to 0.71120, saving model to /content/saved_models/cifar10_ResNet18v1_model.007.h5
# Epoch 8/50
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.9015 - acc: 0.7519 - val_loss: 1.0397 - val_acc: 0.7167
#
# Epoch 00008: val_acc improved from 0.71120 to 0.71670, saving model to /content/saved_models/cifar10_ResNet18v1_model.008.h5
# Epoch 9/50
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.8647 - acc: 0.7649 - val_loss: 1.0833 - val_acc: 0.6945
#
# Epoch 00009: val_acc did not improve from 0.71670
# Epoch 10/50
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.8331 - acc: 0.7760 - val_loss: 1.1309 - val_acc: 0.7027
#
# Epoch 00010: val_acc did not improve from 0.71670
# Epoch 11/50
# Learning rate:  0.001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.8103 - acc: 0.7850 - val_loss: 0.8474 - val_acc: 0.7751
#
# Epoch 00011: val_acc improved from 0.71670 to 0.77510, saving model to /content/saved_models/cifar10_ResNet18v1_model.011.h5
# Epoch 12/50
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.7854 - acc: 0.7925 - val_loss: 0.8549 - val_acc: 0.7724
#
# Epoch 00012: val_acc did not improve from 0.77510
# Epoch 13/50
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.7613 - acc: 0.8028 - val_loss: 0.9087 - val_acc: 0.7547
#
# Epoch 00013: val_acc did not improve from 0.77510
# Epoch 14/50
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.7431 - acc: 0.8085 - val_loss: 1.2600 - val_acc: 0.6779
#
# Epoch 00014: val_acc did not improve from 0.77510
# Epoch 15/50
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.7355 - acc: 0.8092 - val_loss: 1.1844 - val_acc: 0.6880
#
# Epoch 00015: val_acc did not improve from 0.77510
# Epoch 16/50
# Learning rate:  0.001
# 391/391 [==============================] - 43s 111ms/step - loss: 0.7213 - acc: 0.8159 - val_loss: 0.7525 - val_acc: 0.8134
#
# Epoch 00016: val_acc improved from 0.77510 to 0.81340, saving model to /content/saved_models/cifar10_ResNet18v1_model.016.h5
# Epoch 17/50
# Learning rate:  0.001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.7017 - acc: 0.8244 - val_loss: 1.0118 - val_acc: 0.7554
#
# Epoch 00017: val_acc did not improve from 0.81340
# Epoch 18/50
# Learning rate:  0.001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.6918 - acc: 0.8265 - val_loss: 1.0012 - val_acc: 0.7370
#
# Epoch 00018: val_acc did not improve from 0.81340
# Epoch 19/50
# Learning rate:  0.001
# 391/391 [==============================] - 45s 115ms/step - loss: 0.6811 - acc: 0.8310 - val_loss: 0.9790 - val_acc: 0.7439
#
# Epoch 00019: val_acc did not improve from 0.81340
# Epoch 20/50
# Learning rate:  0.001
# 391/391 [==============================] - 45s 115ms/step - loss: 0.6705 - acc: 0.8346 - val_loss: 0.9299 - val_acc: 0.7720
#
# Epoch 00020: val_acc did not improve from 0.81340
# Epoch 21/50
# Learning rate:  0.001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6611 - acc: 0.8387 - val_loss: 0.8528 - val_acc: 0.7808
#
# Epoch 00021: val_acc did not improve from 0.81340
# Epoch 22/50
# Learning rate:  0.001
# 391/391 [==============================] - 45s 115ms/step - loss: 0.6537 - acc: 0.8405 - val_loss: 1.0016 - val_acc: 0.7441
#
# Epoch 00022: val_acc did not improve from 0.81340
# Epoch 23/50
# Learning rate:  0.001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.6438 - acc: 0.8453 - val_loss: 0.8760 - val_acc: 0.7842
#
# Epoch 00023: val_acc did not improve from 0.81340
# Epoch 24/50
# Learning rate:  0.001
# 391/391 [==============================] - 45s 115ms/step - loss: 0.6364 - acc: 0.8482 - val_loss: 1.1056 - val_acc: 0.7238
#
# Epoch 00024: val_acc did not improve from 0.81340
# Epoch 25/50
# Learning rate:  0.001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.6290 - acc: 0.8502 - val_loss: 0.9081 - val_acc: 0.7728
#
# Epoch 00025: val_acc did not improve from 0.81340
# Epoch 26/50
# Learning rate:  0.001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.6221 - acc: 0.8514 - val_loss: 0.7928 - val_acc: 0.8028
#
# Epoch 00026: val_acc did not improve from 0.81340
# Epoch 27/50
# Learning rate:  0.0001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.5366 - acc: 0.8820 - val_loss: 0.5870 - val_acc: 0.8696
#
# Epoch 00027: val_acc improved from 0.81340 to 0.86960, saving model to /content/saved_models/cifar10_ResNet18v1_model.027.h5
# Epoch 28/50
# Learning rate:  0.0001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.5059 - acc: 0.8927 - val_loss: 0.5720 - val_acc: 0.8765
#
# Epoch 00028: val_acc improved from 0.86960 to 0.87650, saving model to /content/saved_models/cifar10_ResNet18v1_model.028.h5
# Epoch 29/50
# Learning rate:  0.0001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.4959 - acc: 0.8957 - val_loss: 0.5672 - val_acc: 0.8750
#
# Epoch 00029: val_acc did not improve from 0.87650
# Epoch 30/50
# Learning rate:  0.0001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.4867 - acc: 0.8959 - val_loss: 0.5627 - val_acc: 0.8771
#
# Epoch 00030: val_acc improved from 0.87650 to 0.87710, saving model to /content/saved_models/cifar10_ResNet18v1_model.030.h5
# Epoch 31/50
# Learning rate:  0.0001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.4768 - acc: 0.8983 - val_loss: 0.5599 - val_acc: 0.8787
#
# Epoch 00031: val_acc improved from 0.87710 to 0.87870, saving model to /content/saved_models/cifar10_ResNet18v1_model.031.h5
# Epoch 32/50
# Learning rate:  0.0001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.4658 - acc: 0.9029 - val_loss: 0.5505 - val_acc: 0.8821
#
# Epoch 00032: val_acc improved from 0.87870 to 0.88210, saving model to /content/saved_models/cifar10_ResNet18v1_model.032.h5
# Epoch 33/50
# Learning rate:  0.0001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.4554 - acc: 0.9060 - val_loss: 0.5509 - val_acc: 0.8799
#
# Epoch 00033: val_acc did not improve from 0.88210
# Epoch 34/50
# Learning rate:  0.0001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4525 - acc: 0.9058 - val_loss: 0.5606 - val_acc: 0.8778
#
# Epoch 00034: val_acc did not improve from 0.88210
# Epoch 35/50
# Learning rate:  0.0001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.4462 - acc: 0.9082 - val_loss: 0.5498 - val_acc: 0.8782
#
# Epoch 00035: val_acc did not improve from 0.88210
# Epoch 36/50
# Learning rate:  0.0001
# 391/391 [==============================] - 46s 116ms/step - loss: 0.4366 - acc: 0.9110 - val_loss: 0.5438 - val_acc: 0.8804
#
# Epoch 00036: val_acc did not improve from 0.88210
# Epoch 37/50
# Learning rate:  0.0001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4357 - acc: 0.9097 - val_loss: 0.5495 - val_acc: 0.8811
#
# Epoch 00037: val_acc did not improve from 0.88210
# Epoch 38/50
# Learning rate:  0.0001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.4241 - acc: 0.9132 - val_loss: 0.5430 - val_acc: 0.8796
#
# Epoch 00038: val_acc did not improve from 0.88210
# Epoch 39/50
# Learning rate:  0.0001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4241 - acc: 0.9122 - val_loss: 0.5449 - val_acc: 0.8816
#
# Epoch 00039: val_acc did not improve from 0.88210
# Epoch 40/50
# Learning rate:  0.0001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4215 - acc: 0.9134 - val_loss: 0.5490 - val_acc: 0.8797
#
# Epoch 00040: val_acc did not improve from 0.88210
# Epoch 41/50
# Learning rate:  0.0001
# 391/391 [==============================] - 46s 116ms/step - loss: 0.4151 - acc: 0.9148 - val_loss: 0.5458 - val_acc: 0.8790
#
# Epoch 00041: val_acc did not improve from 0.88210
# Epoch 42/50
# Learning rate:  0.0001
# 391/391 [==============================] - 45s 115ms/step - loss: 0.4102 - acc: 0.9172 - val_loss: 0.5440 - val_acc: 0.8802
#
# Epoch 00042: val_acc did not improve from 0.88210
# Epoch 43/50
# Learning rate:  0.0001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4087 - acc: 0.9175 - val_loss: 0.5499 - val_acc: 0.8790
#
# Epoch 00043: val_acc did not improve from 0.88210
# Epoch 44/50
# Learning rate:  0.0001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4062 - acc: 0.9175 - val_loss: 0.5486 - val_acc: 0.8806
#
# Epoch 00044: val_acc did not improve from 0.88210
# Epoch 45/50
# Learning rate:  0.0001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.3988 - acc: 0.9187 - val_loss: 0.5587 - val_acc: 0.8755
#
# Epoch 00045: val_acc did not improve from 0.88210
# Epoch 46/50
# Learning rate:  0.0001
# 391/391 [==============================] - 44s 111ms/step - loss: 0.3968 - acc: 0.9198 - val_loss: 0.5511 - val_acc: 0.8806
#
# Epoch 00046: val_acc did not improve from 0.88210
# Epoch 47/50
# Learning rate:  5e-05
# 391/391 [==============================] - 44s 114ms/step - loss: 0.3846 - acc: 0.9241 - val_loss: 0.5346 - val_acc: 0.8828
#
# Epoch 00047: val_acc improved from 0.88210 to 0.88280, saving model to /content/saved_models/cifar10_ResNet18v1_model.047.h5
# Epoch 48/50
# Learning rate:  5e-05
# 391/391 [==============================] - 44s 114ms/step - loss: 0.3815 - acc: 0.9236 - val_loss: 0.5320 - val_acc: 0.8832
#
# Epoch 00048: val_acc improved from 0.88280 to 0.88320, saving model to /content/saved_models/cifar10_ResNet18v1_model.048.h5
# Epoch 49/50
# Learning rate:  5e-05
# 391/391 [==============================] - 44s 113ms/step - loss: 0.3779 - acc: 0.9259 - val_loss: 0.5331 - val_acc: 0.8804
#
# Epoch 00049: val_acc did not improve from 0.88320
# Epoch 50/50
# Learning rate:  5e-05
# 391/391 [==============================] - 44s 114ms/step - loss: 0.3779 - acc: 0.9255 - val_loss: 0.5248 - val_acc: 0.8858
#
# Epoch 00050: val_acc improved from 0.88320 to 0.88580, saving model to /content/saved_models/cifar10_ResNet18v1_model.050.h5

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
# Fit the model on the batches generated by datagen.flow().
model_info=model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=2, workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
plot_model_history(model_info)
# Out:
# Epoch 1/50
# Learning rate:  0.001
#  - 42s - loss: 0.5590 - acc: 0.8639 - val_loss: 0.8129 - val_acc: 0.8071
#
# Epoch 00001: val_acc did not improve from 0.88580
# Epoch 2/50
# Learning rate:  0.001
#  - 41s - loss: 0.5601 - acc: 0.8661 - val_loss: 1.1279 - val_acc: 0.7391
#
# Epoch 00002: val_acc did not improve from 0.88580
# Epoch 3/50
# Learning rate:  0.001
#  - 41s - loss: 0.5536 - acc: 0.8707 - val_loss: 0.8210 - val_acc: 0.8033
#
# Epoch 00003: val_acc did not improve from 0.88580
# Epoch 4/50
# Learning rate:  0.001
#  - 42s - loss: 0.5607 - acc: 0.8701 - val_loss: 0.7506 - val_acc: 0.8134
#
# Epoch 00004: val_acc did not improve from 0.88580
# Epoch 5/50
# Learning rate:  0.001
#  - 43s - loss: 0.5570 - acc: 0.8707 - val_loss: 1.0165 - val_acc: 0.7496
#
# Epoch 00005: val_acc did not improve from 0.88580
# Epoch 6/50
# Learning rate:  0.001
#  - 42s - loss: 0.5572 - acc: 0.8718 - val_loss: 0.9088 - val_acc: 0.7743
#
# Epoch 00006: val_acc did not improve from 0.88580
# Epoch 7/50
# Learning rate:  0.001
#  - 42s - loss: 0.5553 - acc: 0.8728 - val_loss: 0.8081 - val_acc: 0.8128
#
# Epoch 00007: val_acc did not improve from 0.88580
# Epoch 8/50
# Learning rate:  0.001
#  - 42s - loss: 0.5572 - acc: 0.8736 - val_loss: 0.7999 - val_acc: 0.8161
#
# Epoch 00008: val_acc did not improve from 0.88580
# Epoch 9/50
# Learning rate:  0.001
#  - 41s - loss: 0.5637 - acc: 0.8709 - val_loss: 0.7960 - val_acc: 0.8107
#
# Epoch 00009: val_acc did not improve from 0.88580
# Epoch 10/50
# Learning rate:  0.001
#  - 42s - loss: 0.5544 - acc: 0.8763 - val_loss: 0.7425 - val_acc: 0.8269
#
# Epoch 00010: val_acc did not improve from 0.88580
# Epoch 11/50
# Learning rate:  0.001
#  - 41s - loss: 0.5548 - acc: 0.8757 - val_loss: 0.7355 - val_acc: 0.8213
#
# Epoch 00011: val_acc did not improve from 0.88580
# Epoch 12/50
# Learning rate:  0.001
#  - 41s - loss: 0.5489 - acc: 0.8797 - val_loss: 0.7663 - val_acc: 0.8109
#
# Epoch 00012: val_acc did not improve from 0.88580
# Epoch 13/50
# Learning rate:  0.001
#  - 42s - loss: 0.5499 - acc: 0.8783 - val_loss: 0.7506 - val_acc: 0.8245
#
# Epoch 00013: val_acc did not improve from 0.88580
# Epoch 14/50
# Learning rate:  0.001
#  - 42s - loss: 0.5509 - acc: 0.8788 - val_loss: 0.6939 - val_acc: 0.8447
#
# Epoch 00014: val_acc did not improve from 0.88580
# Epoch 15/50
# Learning rate:  0.001
#  - 41s - loss: 0.5409 - acc: 0.8825 - val_loss: 0.7170 - val_acc: 0.8350
#
# Epoch 00015: val_acc did not improve from 0.88580
# Epoch 16/50
# Learning rate:  0.001
#  - 40s - loss: 0.5427 - acc: 0.8819 - val_loss: 0.7329 - val_acc: 0.8269
#
# Epoch 00016: val_acc did not improve from 0.88580
# Epoch 17/50
# Learning rate:  0.001
#  - 41s - loss: 0.5428 - acc: 0.8812 - val_loss: 0.8377 - val_acc: 0.8089
#
# Epoch 00017: val_acc did not improve from 0.88580
# Epoch 18/50
# Learning rate:  0.001
#  - 42s - loss: 0.5422 - acc: 0.8819 - val_loss: 1.0633 - val_acc: 0.7547
#
# Epoch 00018: val_acc did not improve from 0.88580
# Epoch 19/50
# Learning rate:  0.001
#  - 42s - loss: 0.5313 - acc: 0.8869 - val_loss: 0.7520 - val_acc: 0.8226
#
# Epoch 00019: val_acc did not improve from 0.88580
# Epoch 20/50
# Learning rate:  0.001
#  - 42s - loss: 0.5345 - acc: 0.8843 - val_loss: 0.8781 - val_acc: 0.7998
#
# Epoch 00020: val_acc did not improve from 0.88580
# Epoch 21/50
# Learning rate:  0.001
#  - 41s - loss: 0.5320 - acc: 0.8864 - val_loss: 0.7175 - val_acc: 0.8321
#
# Epoch 00021: val_acc did not improve from 0.88580
# Epoch 22/50
# Learning rate:  0.001
#  - 41s - loss: 0.5375 - acc: 0.8824 - val_loss: 0.7654 - val_acc: 0.8215
#
# Epoch 00022: val_acc did not improve from 0.88580
# Epoch 23/50
# Learning rate:  0.001
#  - 41s - loss: 0.5269 - acc: 0.8882 - val_loss: 0.7292 - val_acc: 0.8293
#
# Epoch 00023: val_acc did not improve from 0.88580
# Epoch 24/50
# Learning rate:  0.001
#  - 42s - loss: 0.5287 - acc: 0.8862 - val_loss: 0.7787 - val_acc: 0.8197
#
# Epoch 00024: val_acc did not improve from 0.88580
# Epoch 25/50
# Learning rate:  0.001
#  - 42s - loss: 0.5237 - acc: 0.8892 - val_loss: 0.8126 - val_acc: 0.8075
#
# Epoch 00025: val_acc did not improve from 0.88580
# Epoch 26/50
# Learning rate:  0.001
#  - 41s - loss: 0.5275 - acc: 0.8877 - val_loss: 0.8121 - val_acc: 0.8179
#
# Epoch 00026: val_acc did not improve from 0.88580
# Epoch 27/50
# Learning rate:  0.0001
#  - 41s - loss: 0.4513 - acc: 0.9142 - val_loss: 0.5394 - val_acc: 0.8883
#
# Epoch 00027: val_acc improved from 0.88580 to 0.88830, saving model to /content/saved_models/cifar10_ResNet18v1_model.027.h5
# Epoch 28/50
# Learning rate:  0.0001
#  - 41s - loss: 0.4220 - acc: 0.9252 - val_loss: 0.5357 - val_acc: 0.8899
#
# Epoch 00028: val_acc improved from 0.88830 to 0.88990, saving model to /content/saved_models/cifar10_ResNet18v1_model.028.h5
# Epoch 29/50
# Learning rate:  0.0001
#  - 42s - loss: 0.4089 - acc: 0.9287 - val_loss: 0.5318 - val_acc: 0.8905
#
# Epoch 00029: val_acc improved from 0.88990 to 0.89050, saving model to /content/saved_models/cifar10_ResNet18v1_model.029.h5
# Epoch 30/50
# Learning rate:  0.0001
#  - 40s - loss: 0.3994 - acc: 0.9314 - val_loss: 0.5218 - val_acc: 0.8954
#
# Epoch 00030: val_acc improved from 0.89050 to 0.89540, saving model to /content/saved_models/cifar10_ResNet18v1_model.030.h5
# Epoch 31/50
# Learning rate:  0.0001
#  - 40s - loss: 0.3911 - acc: 0.9333 - val_loss: 0.5215 - val_acc: 0.8948
#
# Epoch 00031: val_acc did not improve from 0.89540
# Epoch 32/50
# Learning rate:  0.0001
#  - 40s - loss: 0.3869 - acc: 0.9338 - val_loss: 0.5196 - val_acc: 0.8966
#
# Epoch 00032: val_acc improved from 0.89540 to 0.89660, saving model to /content/saved_models/cifar10_ResNet18v1_model.032.h5
# Epoch 33/50
# Learning rate:  0.0001
#  - 40s - loss: 0.3800 - acc: 0.9358 - val_loss: 0.5203 - val_acc: 0.8968
#
# Epoch 00033: val_acc improved from 0.89660 to 0.89680, saving model to /content/saved_models/cifar10_ResNet18v1_model.033.h5
# Epoch 34/50
# Learning rate:  0.0001
#  - 40s - loss: 0.3691 - acc: 0.9380 - val_loss: 0.5299 - val_acc: 0.8938
#
# Epoch 00034: val_acc did not improve from 0.89680
# Epoch 35/50
# Learning rate:  0.0001
#  - 40s - loss: 0.3620 - acc: 0.9399 - val_loss: 0.5221 - val_acc: 0.8961
#
# Epoch 00035: val_acc did not improve from 0.89680
# Epoch 36/50
# Learning rate:  0.0001
#  - 42s - loss: 0.3615 - acc: 0.9397 - val_loss: 0.5061 - val_acc: 0.9007
#
# Epoch 00036: val_acc improved from 0.89680 to 0.90070, saving model to /content/saved_models/cifar10_ResNet18v1_model.036.h5
# Epoch 37/50
# Learning rate:  0.0001
#  - 42s - loss: 0.3573 - acc: 0.9414 - val_loss: 0.5000 - val_acc: 0.9031
#
# Epoch 00037: val_acc improved from 0.90070 to 0.90310, saving model to /content/saved_models/cifar10_ResNet18v1_model.037.h5
# Epoch 38/50
# Learning rate:  0.0001
#  - 41s - loss: 0.3503 - acc: 0.9431 - val_loss: 0.5215 - val_acc: 0.8955
#
# Epoch 00038: val_acc did not improve from 0.90310
# Epoch 39/50
# Learning rate:  0.0001
#  - 41s - loss: 0.3467 - acc: 0.9436 - val_loss: 0.5054 - val_acc: 0.9003
#
# Epoch 00039: val_acc did not improve from 0.90310
# Epoch 40/50
# Learning rate:  0.0001
#  - 41s - loss: 0.3392 - acc: 0.9460 - val_loss: 0.5125 - val_acc: 0.8997
#
# Epoch 00040: val_acc did not improve from 0.90310
# Epoch 41/50
# Learning rate:  0.0001
#  - 41s - loss: 0.3411 - acc: 0.9448 - val_loss: 0.5273 - val_acc: 0.8925
#
# Epoch 00041: val_acc did not improve from 0.90310
# Epoch 42/50
# Learning rate:  0.0001
#  - 41s - loss: 0.3344 - acc: 0.9460 - val_loss: 0.5027 - val_acc: 0.9007
#
# Epoch 00042: val_acc did not improve from 0.90310
# Epoch 43/50
# Learning rate:  0.0001
#  - 41s - loss: 0.3308 - acc: 0.9467 - val_loss: 0.5055 - val_acc: 0.8998
#
# Epoch 00043: val_acc did not improve from 0.90310
# Epoch 44/50
# Learning rate:  0.0001
#  - 41s - loss: 0.3272 - acc: 0.9480 - val_loss: 0.5011 - val_acc: 0.9005
#
# Epoch 00044: val_acc did not improve from 0.90310
# Epoch 45/50
# Learning rate:  0.0001
#  - 41s - loss: 0.3213 - acc: 0.9491 - val_loss: 0.5191 - val_acc: 0.8985
#
# Epoch 00045: val_acc did not improve from 0.90310
# Epoch 46/50
# Learning rate:  0.0001
#  - 42s - loss: 0.3268 - acc: 0.9469 - val_loss: 0.5114 - val_acc: 0.9001
#
# Epoch 00046: val_acc did not improve from 0.90310
# Epoch 47/50
# Learning rate:  5e-05
#  - 42s - loss: 0.3165 - acc: 0.9510 - val_loss: 0.4921 - val_acc: 0.9024
#
# Epoch 00047: val_acc did not improve from 0.90310
# Epoch 48/50
# Learning rate:  5e-05
#  - 42s - loss: 0.3125 - acc: 0.9513 - val_loss: 0.4968 - val_acc: 0.9037
#
# Epoch 00048: val_acc improved from 0.90310 to 0.90370, saving model to /content/saved_models/cifar10_ResNet18v1_model.048.h5
# Epoch 49/50
# Learning rate:  5e-05
#  - 41s - loss: 0.3089 - acc: 0.9526 - val_loss: 0.4906 - val_acc: 0.9034
#
# Epoch 00049: val_acc did not improve from 0.90370
# Epoch 50/50
# Learning rate:  5e-05
#  - 41s - loss: 0.3064 - acc: 0.9527 - val_loss: 0.4932 - val_acc: 0.9030
#
# Epoch 00050: val_acc did not improve from 0.90370
# 10000/10000 [==============================] - 2s 210us/step
# Test loss: 0.49323331780433655
# Test accuracy: 0.903
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-69d2e732c6a6> in <module>()
#       8 print('Test loss:', scores[0])
#       9 print('Test accuracy:', scores[1])
# ---> 10 plot_model_history(model_info)
#
# <ipython-input-10-6d786bb69f7f> in plot_model_history(model_history)
#       1
#       2 def plot_model_history(model_history):
# ----> 3     fig, axs = plt.subplots(1,2,figsize=(15,5))
#       4     # summarize history for accuracy
#       5     axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
#
# NameError: name 'plt' is not defined
